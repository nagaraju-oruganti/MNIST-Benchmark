# %%
# %%capture
from google.colab import drive
drive.flush_and_unmount()
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/Developer/personal/MNIST Benchmark/src

# %%
# %%capture
# !pip install idx2numpy

# %%
from helper_config import Config
from helper_trainer import train

config = Config()
config.data_dir = '../inputs/mnist'
config.models_dir = '../models'
config.model_name = 'snn_baseline'
config.train_batch_size = 64
config.valid_batch_size = 128
config.iters_to_accumlate = 1
config.learning_rate = 1e-4
config.num_epochs = 1000

config.save_epoch_wait = 1
config.early_stop_count = 20
config.save_checkpoint = True

config.time_steps = 3
config.train_arch = 'SNN'

results = train(config)
# Out:
# set seed to 3407
# 100%|██████████| 750/750 [00:16<00:00, 45.05it/s, batch_loss=0.293117, epoch_loss=0.982768, learning_rate=0.0001]
# >>> [2023-08-10 17:23:47.633544 | 1/1000 | Early stopping counter 0]
#     loss          - train: 0.309850      valid: 0.307300
#     f1-score      - train: 0.907737      valid: 0.909378
#     accuracy      - train: 0.907854      valid: 0.909667
#     learning rate        : 1.00000e-04
# 100%|██████████| 750/750 [00:12<00:00, 58.69it/s, batch_loss=0.139154, epoch_loss=0.242523, learning_rate=0.0001]
# >>> [2023-08-10 17:24:06.236884] - Checkpoint and predictions saved
#
# >>> [2023-08-10 17:24:06.238968 | 2/1000 | Early stopping counter 0]
#     loss          - train: 0.163135      valid: 0.165589
#     f1-score      - train: 0.950822      valid: 0.949534
#     accuracy      - train: 0.950729      valid: 0.949417
#     learning rate        : 1.00000e-04
# 100%|██████████| 750/750 [00:13<00:00, 57.27it/s, batch_loss=0.025063, epoch_loss=0.151351, learning_rate=0.0001]
# >>> [2023-08-10 17:24:23.583548] - Checkpoint and predictions saved
#
# >>> [2023-08-10 17:24:23.583939 | 3/1000 | Early stopping counter 0]
#     loss          - train: 0.129584      valid: 0.131811
#     f1-score      - train: 0.960900      valid: 0.960764
#     accuracy      - train: 0.960875      valid: 0.960750
#     learning rate        : 1.00000e-04
# 100%|██████████| 750/750 [00:12<00:00, 58.95it/s, batch_loss=0.095616, epoch_loss=0.104766, learning_rate=0.0001]
# >>> [2023-08-10 17:24:41.323193] - Checkpoint and predictions saved
#
# >>> [2023-08-10 17:24:41.324942 | 4/1000 | Early stopping counter 0]
#     loss          - train: 0.080978      valid: 0.095329
#     f1-score      - train: 0.974711      valid: 0.969461
#     accuracy      - train: 0.974750      valid: 0.969500
#     learning rate        : 1.00000e-04
# 100%|██████████| 750/750 [00:12<00:00, 58.98it/s, batch_loss=0.143824, epoch_loss=0.075978, learning_rate=0.0001]
# >>> [2023-08-10 17:24:58.479335] - Checkpoint and predictions saved
#
# >>> [2023-08-10 17:24:58.484121 | 5/1000 | Early stopping counter 0]
#     loss          - train: 0.050900      valid: 0.074497
#     f1-score      - train: 0.984857      valid: 0.976668
#     accuracy      - train: 0.984854      valid: 0.976667
#     learning rate        : 1.00000e-04
# 100%|██████████| 750/750 [00:12<00:00, 57.70it/s, batch_loss=0.101037, epoch_loss=0.058713, learning_rate=0.0001]
# >>> [2023-08-10 17:25:15.707242] - Checkpoint and predictions saved
#
# >>> [2023-08-10 17:25:15.709074 | 6/1000 | Early stopping counter 0]
#     loss          - train: 0.038683      valid: 0.066904
#     f1-score      - train: 0.988235      valid: 0.980338
#     accuracy      - train: 0.988229      valid: 0.980333
#     learning rate        : 1.00000e-04
# 100%|██████████| 750/750 [00:12<00:00, 58.55it/s, batch_loss=0.037518, epoch_loss=0.043338, learning_rate=0.0001]
# >>> [2023-08-10 17:25:32.026227 | 7/1000 | Early stopping counter 1]
#     loss          - train: 0.031666      valid: 0.065924
#     f1-score      - train: 0.990258      valid: 0.979917
#     accuracy      - train: 0.990250      valid: 0.979917
#     learning rate        : 1.00000e-04
# 100%|██████████| 750/750 [00:12<00:00, 59.67it/s, batch_loss=0.001101, epoch_loss=0.034461, learning_rate=0.0001]
# >>> [2023-08-10 17:25:48.491770 | 8/1000 | Early stopping counter 2]
#     loss          - train: 0.031462      valid: 0.073529
#     f1-score      - train: 0.989806      valid: 0.979900
#     accuracy      - train: 0.989812      valid: 0.979917
#     learning rate        : 1.00000e-04
# 100%|██████████| 750/750 [00:12<00:00, 58.44it/s, batch_loss=0.034997, epoch_loss=0.027304, learning_rate=0.0001]
# >>> [2023-08-10 17:26:05.206445] - Checkpoint and predictions saved
#
# >>> [2023-08-10 17:26:05.209001 | 9/1000 | Early stopping counter 0]
#     loss          - train: 0.021208      valid: 0.065445
#     f1-score      - train: 0.993231      valid: 0.981928
#     accuracy      - train: 0.993229      valid: 0.981917
#     learning rate        : 1.00000e-04
# 100%|██████████| 750/750 [00:12<00:00, 58.98it/s, batch_loss=0.012657, epoch_loss=0.021665, learning_rate=0.0001]
# >>> [2023-08-10 17:26:22.441183] - Checkpoint and predictions saved
#
# >>> [2023-08-10 17:26:22.442840 | 10/1000 | Early stopping counter 0]
#     loss          - train: 0.012348      valid: 0.063373
#     f1-score      - train: 0.996542      valid: 0.983078
#     accuracy      - train: 0.996542      valid: 0.983083
#     learning rate        : 1.00000e-04
# 100%|██████████| 750/750 [00:12<00:00, 59.50it/s, batch_loss=0.010190, epoch_loss=0.016976, learning_rate=0.0001]
# >>> [2023-08-10 17:26:39.438730 | 11/1000 | Early stopping counter 1]
#     loss          - train: 0.011534      valid: 0.064396
#     f1-score      - train: 0.996686      valid: 0.982742
#     accuracy      - train: 0.996687      valid: 0.982750
#     learning rate        : 1.00000e-04
# 100%|██████████| 750/750 [00:12<00:00, 61.24it/s, batch_loss=0.001384, epoch_loss=0.011487, learning_rate=0.0001]
# >>> [2023-08-10 17:26:55.889781 | 12/1000 | Early stopping counter 2]
#     loss          - train: 0.008850      valid: 0.069022
#     f1-score      - train: 0.997061      valid: 0.982993
#     accuracy      - train: 0.997062      valid: 0.983000
#     learning rate        : 1.00000e-04
# 100%|██████████| 750/750 [00:12<00:00, 61.56it/s, batch_loss=0.002010, epoch_loss=0.012236, learning_rate=0.0001]
# >>> [2023-08-10 17:27:11.917231 | 13/1000 | Early stopping counter 3]
#     loss          - train: 0.013558      valid: 0.080762
#     f1-score      - train: 0.995478      valid: 0.980015
#     accuracy      - train: 0.995479      valid: 0.980000
#     learning rate        : 1.00000e-04
# 100%|██████████| 750/750 [00:12<00:00, 60.24it/s, batch_loss=0.001768, epoch_loss=0.008722, learning_rate=0.0001]
# >>> [2023-08-10 17:27:28.218150] - Checkpoint and predictions saved
#
# >>> [2023-08-10 17:27:28.221524 | 14/1000 | Early stopping counter 0]
#     loss          - train: 0.006960      valid: 0.072599
#     f1-score      - train: 0.997708      valid: 0.984072
#     accuracy      - train: 0.997708      valid: 0.984083
#     learning rate        : 1.00000e-04
# 100%|██████████| 750/750 [00:12<00:00, 58.83it/s, batch_loss=0.001885, epoch_loss=0.009323, learning_rate=0.0001]
# >>> [2023-08-10 17:27:44.510962 | 15/1000 | Early stopping counter 1]
#     loss          - train: 0.006953      valid: 0.074134
#     f1-score      - train: 0.997938      valid: 0.982162
#     accuracy      - train: 0.997938      valid: 0.982167
#     learning rate        : 1.00000e-04
# 100%|██████████| 750/750 [00:12<00:00, 60.29it/s, batch_loss=0.005638, epoch_loss=0.005463, learning_rate=0.0001]
# >>> [2023-08-10 17:28:00.420672 | 16/1000 | Early stopping counter 2]
#     loss          - train: 0.010812      valid: 0.090092
#     f1-score      - train: 0.996166      valid: 0.981242
#     accuracy      - train: 0.996167      valid: 0.981250
#     learning rate        : 1.00000e-04
# 100%|██████████| 750/750 [00:12<00:00, 60.02it/s, batch_loss=0.002147, epoch_loss=0.008126, learning_rate=0.0001]
# >>> [2023-08-10 17:28:16.755356] - Checkpoint and predictions saved
#
# >>> [2023-08-10 17:28:16.756957 | 17/1000 | Early stopping counter 0]
#     loss          - train: 0.003660      valid: 0.068513
#     f1-score      - train: 0.999083      valid: 0.984921
#     accuracy      - train: 0.999083      valid: 0.984917
#     learning rate        : 1.00000e-04
# 100%|██████████| 750/750 [00:12<00:00, 60.30it/s, batch_loss=0.003600, epoch_loss=0.004668, learning_rate=0.0001]
# >>> [2023-08-10 17:28:32.708355 | 18/1000 | Early stopping counter 1]
#     loss          - train: 0.026576      valid: 0.104088
#     f1-score      - train: 0.991060      valid: 0.976173
#     accuracy      - train: 0.991000      valid: 0.976000
#     learning rate        : 1.00000e-04
# 100%|██████████| 750/750 [00:12<00:00, 59.70it/s, batch_loss=0.000040, epoch_loss=0.005117, learning_rate=0.0001]
# >>> [2023-08-10 17:28:49.158852] - Checkpoint and predictions saved
#
# >>> [2023-08-10 17:28:49.160755 | 19/1000 | Early stopping counter 0]
#     loss          - train: 0.001545      valid: 0.074643
#     f1-score      - train: 0.999479      valid: 0.985749
#     accuracy      - train: 0.999479      valid: 0.985750
#     learning rate        : 1.00000e-04
# 100%|██████████| 750/750 [00:13<00:00, 57.67it/s, batch_loss=0.001012, epoch_loss=0.005123, learning_rate=0.0001]
# >>> [2023-08-10 17:29:05.797806 | 20/1000 | Early stopping counter 1]
#     loss          - train: 0.002027      valid: 0.081601
#     f1-score      - train: 0.999521      valid: 0.984582
#     accuracy      - train: 0.999521      valid: 0.984583
#     learning rate        : 1.00000e-04
# 100%|██████████| 750/750 [00:12<00:00, 59.95it/s, batch_loss=0.001993, epoch_loss=0.005947, learning_rate=0.0001]
# >>> [2023-08-10 17:29:22.294858 | 21/1000 | Early stopping counter 2]
#     loss          - train: 0.003186      valid: 0.079498
#     f1-score      - train: 0.999000      valid: 0.984562
#     accuracy      - train: 0.999000      valid: 0.984583
#     learning rate        : 1.00000e-04
# 100%|██████████| 750/750 [00:12<00:00, 58.81it/s, batch_loss=0.001365, epoch_loss=0.003384, learning_rate=0.0001]
# >>> [2023-08-10 17:29:39.730623 | 22/1000 | Early stopping counter 3]
#     loss          - train: 0.002780      valid: 0.084448
#     f1-score      - train: 0.999167      valid: 0.984824
#     accuracy      - train: 0.999167      valid: 0.984833
#     learning rate        : 1.00000e-04
# 100%|██████████| 750/750 [00:13<00:00, 55.56it/s, batch_loss=0.002144, epoch_loss=0.004470, learning_rate=0.0001]
# >>> [2023-08-10 17:29:57.278554 | 23/1000 | Early stopping counter 4]
#     loss          - train: 0.002319      valid: 0.073739
#     f1-score      - train: 0.999292      valid: 0.983483
#     accuracy      - train: 0.999292      valid: 0.983500
#     learning rate        : 1.00000e-04
# 100%|██████████| 750/750 [00:12<00:00, 60.11it/s, batch_loss=0.000013, epoch_loss=0.003750, learning_rate=0.0001]
# >>> [2023-08-10 17:30:13.529162 | 24/1000 | Early stopping counter 5]
#     loss          - train: 0.002408      valid: 0.077115
#     f1-score      - train: 0.999125      valid: 0.984680
#     accuracy      - train: 0.999125      valid: 0.984667
#     learning rate        : 5.00000e-05
# 100%|██████████| 750/750 [00:12<00:00, 57.84it/s, batch_loss=0.000002, epoch_loss=0.000646, learning_rate=5e-5]
# >>> [2023-08-10 17:30:30.428047] - Checkpoint and predictions saved
#
# >>> [2023-08-10 17:30:30.430234 | 25/1000 | Early stopping counter 0]
#     loss          - train: 0.000090      valid: 0.076033
#     f1-score      - train: 1.000000      valid: 0.987499
#     accuracy      - train: 1.000000      valid: 0.987500
#     learning rate        : 5.00000e-05
# 100%|██████████| 750/750 [00:13<00:00, 56.08it/s, batch_loss=0.000022, epoch_loss=0.000071, learning_rate=5e-5]
# >>> [2023-08-10 17:30:47.769139] - Checkpoint and predictions saved
#
# >>> [2023-08-10 17:30:47.770370 | 26/1000 | Early stopping counter 0]
#     loss          - train: 0.000054      valid: 0.079171
#     f1-score      - train: 1.000000      valid: 0.987664
#     accuracy      - train: 1.000000      valid: 0.987667
#     learning rate        : 5.00000e-05
# 100%|██████████| 750/750 [00:13<00:00, 55.28it/s, batch_loss=0.000006, epoch_loss=0.000039, learning_rate=5e-5]
# >>> [2023-08-10 17:31:05.236269] - Checkpoint and predictions saved
#
# >>> [2023-08-10 17:31:05.237997 | 27/1000 | Early stopping counter 0]
#     loss          - train: 0.000029      valid: 0.082894
#     f1-score      - train: 1.000000      valid: 0.987830
#     accuracy      - train: 1.000000      valid: 0.987833
#     learning rate        : 5.00000e-05
# 100%|██████████| 750/750 [00:13<00:00, 54.40it/s, batch_loss=0.000008, epoch_loss=0.000024, learning_rate=5e-5]
# >>> [2023-08-10 17:31:22.970032 | 28/1000 | Early stopping counter 1]
#     loss          - train: 0.000016      valid: 0.086225
#     f1-score      - train: 1.000000      valid: 0.987581
#     accuracy      - train: 1.000000      valid: 0.987583
#     learning rate        : 5.00000e-05
# 100%|██████████| 750/750 [00:13<00:00, 56.17it/s, batch_loss=0.000008, epoch_loss=0.000015, learning_rate=5e-5]
# >>> [2023-08-10 17:31:40.984528 | 29/1000 | Early stopping counter 2]
#     loss          - train: 0.000011      valid: 0.088891
#     f1-score      - train: 1.000000      valid: 0.987664
#     accuracy      - train: 1.000000      valid: 0.987667
#     learning rate        : 5.00000e-05
# 100%|██████████| 750/750 [00:12<00:00, 58.02it/s, batch_loss=0.000001, epoch_loss=0.000010, learning_rate=5e-5]
# >>> [2023-08-10 17:31:57.898575 | 30/1000 | Early stopping counter 3]
#     loss          - train: 0.000008      valid: 0.092326
#     f1-score      - train: 1.000000      valid: 0.987830
#     accuracy      - train: 1.000000      valid: 0.987833
#     learning rate        : 5.00000e-05
# 100%|██████████| 750/750 [00:13<00:00, 57.00it/s, batch_loss=0.000006, epoch_loss=0.000006, learning_rate=5e-5]
# >>> [2023-08-10 17:32:14.659412 | 31/1000 | Early stopping counter 4]
#     loss          - train: 0.000005      valid: 0.095298
#     f1-score      - train: 1.000000      valid: 0.987830
#     accuracy      - train: 1.000000      valid: 0.987833
#     learning rate        : 5.00000e-05
# 100%|██████████| 750/750 [00:13<00:00, 56.53it/s, batch_loss=0.000000, epoch_loss=0.000005, learning_rate=5e-5]
# >>> [2023-08-10 17:32:32.251887] - Checkpoint and predictions saved
#
# >>> [2023-08-10 17:32:32.255662 | 32/1000 | Early stopping counter 0]
#     loss          - train: 0.000003      valid: 0.098247
#     f1-score      - train: 1.000000      valid: 0.987997
#     accuracy      - train: 1.000000      valid: 0.988000
#     learning rate        : 5.00000e-05
# 100%|██████████| 750/750 [00:13<00:00, 53.70it/s, batch_loss=0.000003, epoch_loss=0.000003, learning_rate=5e-5]
# >>> [2023-08-10 17:32:49.723630 | 33/1000 | Early stopping counter 1]
#     loss          - train: 0.000002      valid: 0.101399
#     f1-score      - train: 1.000000      valid: 0.987746
#     accuracy      - train: 1.000000      valid: 0.987750
#     learning rate        : 5.00000e-05
# 100%|██████████| 750/750 [00:13<00:00, 55.76it/s, batch_loss=0.021861, epoch_loss=0.003322, learning_rate=5e-5]
# >>> [2023-08-10 17:33:06.993931 | 34/1000 | Early stopping counter 2]
#     loss          - train: 0.003308      valid: 0.092514
#     f1-score      - train: 0.999000      valid: 0.983984
#     accuracy      - train: 0.999000      valid: 0.984000
#     learning rate        : 5.00000e-05
# 100%|██████████| 750/750 [00:12<00:00, 57.89it/s, batch_loss=0.000004, epoch_loss=0.000957, learning_rate=5e-5]
# >>> [2023-08-10 17:33:24.440422 | 35/1000 | Early stopping counter 3]
#     loss          - train: 0.000070      valid: 0.081332
#     f1-score      - train: 1.000000      valid: 0.986659
#     accuracy      - train: 1.000000      valid: 0.986667
#     learning rate        : 5.00000e-05
# 100%|██████████| 750/750 [00:12<00:00, 59.19it/s, batch_loss=0.000024, epoch_loss=0.000052, learning_rate=5e-5]
# >>> [2023-08-10 17:33:41.511365 | 36/1000 | Early stopping counter 4]
#     loss          - train: 0.000064      valid: 0.083329
#     f1-score      - train: 0.999979      valid: 0.986742
#     accuracy      - train: 0.999979      valid: 0.986750
#     learning rate        : 5.00000e-05
# 100%|██████████| 750/750 [00:13<00:00, 54.58it/s, batch_loss=0.000001, epoch_loss=0.000029, learning_rate=5e-5]
# >>> [2023-08-10 17:33:59.009592 | 37/1000 | Early stopping counter 5]
#     loss          - train: 0.000016      valid: 0.085843
#     f1-score      - train: 1.000000      valid: 0.986828
#     accuracy      - train: 1.000000      valid: 0.986833
#     learning rate        : 2.50000e-05
# 100%|██████████| 750/750 [00:13<00:00, 55.83it/s, batch_loss=0.000024, epoch_loss=0.000015, learning_rate=2.5e-5]
# >>> [2023-08-10 17:34:16.039044 | 38/1000 | Early stopping counter 6]
#     loss          - train: 0.000012      valid: 0.087364
#     f1-score      - train: 1.000000      valid: 0.986828
#     accuracy      - train: 1.000000      valid: 0.986833
#     learning rate        : 2.50000e-05
# 100%|██████████| 750/750 [00:12<00:00, 58.34it/s, batch_loss=0.000000, epoch_loss=0.000011, learning_rate=2.5e-5]
# >>> [2023-08-10 17:34:32.428004 | 39/1000 | Early stopping counter 7]
#     loss          - train: 0.000009      valid: 0.089191
#     f1-score      - train: 1.000000      valid: 0.986661
#     accuracy      - train: 1.000000      valid: 0.986667
#     learning rate        : 2.50000e-05
# 100%|██████████| 750/750 [00:13<00:00, 55.75it/s, batch_loss=0.000004, epoch_loss=0.000009, learning_rate=2.5e-5]
# >>> [2023-08-10 17:34:49.371753 | 40/1000 | Early stopping counter 8]
#     loss          - train: 0.000007      valid: 0.091074
#     f1-score      - train: 1.000000      valid: 0.986662
#     accuracy      - train: 1.000000      valid: 0.986667
#     learning rate        : 2.50000e-05
# 100%|██████████| 750/750 [00:12<00:00, 58.64it/s, batch_loss=0.000004, epoch_loss=0.000006, learning_rate=2.5e-5]
# >>> [2023-08-10 17:35:05.682990 | 41/1000 | Early stopping counter 9]
#     loss          - train: 0.000005      valid: 0.093481
#     f1-score      - train: 1.000000      valid: 0.986913
#     accuracy      - train: 1.000000      valid: 0.986917
#     learning rate        : 2.50000e-05
# 100%|██████████| 750/750 [00:13<00:00, 56.27it/s, batch_loss=0.000000, epoch_loss=0.000005, learning_rate=2.5e-5]
# >>> [2023-08-10 17:35:22.573508 | 42/1000 | Early stopping counter 10]
#     loss          - train: 0.000003      valid: 0.096291
#     f1-score      - train: 1.000000      valid: 0.986578
#     accuracy      - train: 1.000000      valid: 0.986583
#     learning rate        : 1.25000e-05
# 100%|██████████| 750/750 [00:12<00:00, 58.26it/s, batch_loss=0.000000, epoch_loss=0.000003, learning_rate=1.25e-5]
# >>> [2023-08-10 17:35:39.344202 | 43/1000 | Early stopping counter 11]
#     loss          - train: 0.000003      valid: 0.097922
#     f1-score      - train: 1.000000      valid: 0.986744
#     accuracy      - train: 1.000000      valid: 0.986750
#     learning rate        : 1.25000e-05
# 100%|██████████| 750/750 [00:12<00:00, 59.59it/s, batch_loss=0.000002, epoch_loss=0.000003, learning_rate=1.25e-5]
# >>> [2023-08-10 17:35:56.434209 | 44/1000 | Early stopping counter 12]
#     loss          - train: 0.000002      valid: 0.099701
#     f1-score      - train: 1.000000      valid: 0.986828
#     accuracy      - train: 1.000000      valid: 0.986833
#     learning rate        : 1.25000e-05
# 100%|██████████| 750/750 [00:12<00:00, 59.05it/s, batch_loss=0.000000, epoch_loss=0.000002, learning_rate=1.25e-5]
# >>> [2023-08-10 17:36:13.411186 | 45/1000 | Early stopping counter 13]
#     loss          - train: 0.000002      valid: 0.101898
#     f1-score      - train: 1.000000      valid: 0.987078
#     accuracy      - train: 1.000000      valid: 0.987083
#     learning rate        : 1.25000e-05
# 100%|██████████| 750/750 [00:13<00:00, 57.35it/s, batch_loss=0.000002, epoch_loss=0.000002, learning_rate=1.25e-5]
# >>> [2023-08-10 17:36:30.140025 | 46/1000 | Early stopping counter 14]
#     loss          - train: 0.000001      valid: 0.104281
#     f1-score      - train: 1.000000      valid: 0.986912
#     accuracy      - train: 1.000000      valid: 0.986917
#     learning rate        : 1.25000e-05
# 100%|██████████| 750/750 [00:12<00:00, 58.54it/s, batch_loss=0.000007, epoch_loss=0.000001, learning_rate=1.25e-5]
# >>> [2023-08-10 17:36:46.494448 | 47/1000 | Early stopping counter 15]
#     loss          - train: 0.000001      valid: 0.107024
#     f1-score      - train: 1.000000      valid: 0.987078
#     accuracy      - train: 1.000000      valid: 0.987083
#     learning rate        : 6.25000e-06
# 100%|██████████| 750/750 [00:12<00:00, 59.62it/s, batch_loss=0.000001, epoch_loss=0.000001, learning_rate=6.25e-6]
# >>> [2023-08-10 17:37:02.612712 | 48/1000 | Early stopping counter 16]
#     loss          - train: 0.000001      valid: 0.108634
#     f1-score      - train: 1.000000      valid: 0.987162
#     accuracy      - train: 1.000000      valid: 0.987167
#     learning rate        : 6.25000e-06
# 100%|██████████| 750/750 [00:13<00:00, 55.64it/s, batch_loss=0.000000, epoch_loss=0.000001, learning_rate=6.25e-6]
# >>> [2023-08-10 17:37:19.606835 | 49/1000 | Early stopping counter 17]
#     loss          - train: 0.000001      valid: 0.110372
#     f1-score      - train: 1.000000      valid: 0.987078
#     accuracy      - train: 1.000000      valid: 0.987083
#     learning rate        : 6.25000e-06
# 100%|██████████| 750/750 [00:12<00:00, 58.05it/s, batch_loss=0.000000, epoch_loss=0.000001, learning_rate=6.25e-6]
# >>> [2023-08-10 17:37:36.008751 | 50/1000 | Early stopping counter 18]
#     loss          - train: 0.000000      valid: 0.112481
#     f1-score      - train: 1.000000      valid: 0.987078
#     accuracy      - train: 1.000000      valid: 0.987083
#     learning rate        : 6.25000e-06
# 100%|██████████| 750/750 [00:13<00:00, 55.03it/s, batch_loss=0.000001, epoch_loss=0.000000, learning_rate=6.25e-6]
# >>> [2023-08-10 17:37:53.148753 | 51/1000 | Early stopping counter 19]
#     loss          - train: 0.000000      valid: 0.114901
#     f1-score      - train: 1.000000      valid: 0.986996
#     accuracy      - train: 1.000000      valid: 0.987000
#     learning rate        : 6.25000e-06
# 100%|██████████| 750/750 [00:13<00:00, 56.57it/s, batch_loss=0.000000, epoch_loss=0.000000, learning_rate=6.25e-6]
# >>> [2023-08-10 17:38:09.948997 | 52/1000 | Early stopping counter 20]
#     loss          - train: 0.000000      valid: 0.117709
#     f1-score      - train: 1.000000      valid: 0.986995
#     accuracy      - train: 1.000000      valid: 0.987000
#     learning rate        : 3.12500e-06
